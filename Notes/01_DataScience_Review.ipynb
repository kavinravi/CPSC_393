# %%
# libraries for data wrangling
import pandas as pd
import numpy as np

# library for plotting
from plotnine import *
import matplotlib.pyplot as plt

# ML workflow packages
from sklearn.model_selection import train_test_split,validation_curve
from sklearn.metrics import classification_report, roc_curve, auc,r2_score,mean_squared_error
from sklearn.preprocessing import StandardScaler,LabelEncoder

# ML models
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor

# %% [markdown]
# #### Supervised Machine Learning Model Workflow
# ##### 1. Load Data
# ##### 2. Visualize, Clean, and Preprocess Data
# ##### 3. Create Model Instance
# ##### 4. Fit Model on Data
# ##### 5. Make Predictions and Evaluate Model

# %%
# 1. Load Data
df = pd.read_csv("https://raw.githubusercontent.com/cristobalvch/Spotify-Machine-Learning/refs/heads/master/data/data_moods.csv")
df.head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
#    danceability  acousticness  energy  instrumentalness  liveness  valence  \
# 0         0.866       0.13700   0.730          0.000000    0.0843    0.625
# 1         0.381       0.01890   0.832          0.196000    0.1530    0.166
# 2         0.346       0.91300   0.139          0.000077    0.0934    0.116
# 3         0.466       0.08900   0.438          0.000006    0.1130    0.587
# 4         0.419       0.00171   0.932          0.000000    0.1370    0.445
#
#    loudness  speechiness    tempo  key  time_signature       mood
# 0    -8.201       0.0767  118.523    5               4      Happy
# 1    -5.069       0.0492  120.255    8               4        Sad
# 2   -15.326       0.0321  136.168    0               4        Sad
# 3   -12.858       0.0608  193.100    4               4      Happy
# 4    -3.604       0.1060  169.881    1               4  Energetic

# %%
# 2. Visualize, Clean, and Preprocess Data

# use plotnine's ggplot function to visualize the distribution of energy across moods
(
    ggplot(df, aes(x='energy', fill='factor(mood)'))
    + geom_histogram(bins=30, alpha=0.6, position='identity')
    + labs(title='Energy Distribution by Mood Types', fill='Mood Type')
    + theme_minimal()
)

# %%
# scatter plot of two features color-coded by target variable
(
    ggplot(df, aes(x='loudness', y='danceability', color='factor(mood)'))
    + geom_point(alpha=0.7)
    + labs(title='Loudness vs Danceability across Mood Types', color='Mood Type')
    + theme_minimal()
)

# %% [markdown]
# Let's drop the Happy and Sad classes to make it a binary classification problem

# %%
df = df[(df['mood'] == 'Calm') | (df['mood'] == 'Energetic')]

# %%
df['mood'].value_counts()
# Out:
# mood
# Calm         195
# Energetic    154
# Name: count, dtype: int64

# %%
# set X and y
X = df[['danceability','liveness','length','popularity','acousticness','liveness','tempo','time_signature']]
y = df['mood']

# %%
# one-hot encode time_signature
X = pd.get_dummies(X, columns=['time_signature'])

# %%
# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
# standardization applied to features
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# First, we train a Decision Tree Classifier to predict mood type

# %%
# 3. Create Model Instance
dt_classifier = DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
# 4. Fit Model on Data
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
# 5. Evaluate Model
y_pred = dt_classifier.predict(X_test)
print(f"\n\n Decision Tree Classification Report")
print(classification_report(y_test, y_pred)) # produce classification report
# Out:
#  Decision Tree Classification Report
#               precision    recall  f1-score   support
#
#         Calm       0.93      0.98      0.95        42
#    Energetic       0.96      0.89      0.93        28
#
#     accuracy                           0.94        70
#    macro avg       0.95      0.93      0.94        70
# weighted avg       0.94      0.94      0.94        70

# %%
# 3. Create Model Instance
logistic_model = LogisticRegression()

# 4. Fit Model on Data
logistic_model.fit(X_train, y_train)

# 5. Evaluate Model
y_pred = logistic_model.predict(X_test)
print(f"\n\n Decision Tree Classification Report")
print(classification_report(y_test, y_pred)) # produce classification report
# Out:
#  Decision Tree Classification Report
#               precision    recall  f1-score   support
#
#         Calm       1.00      1.00      1.00        42
#    Energetic       1.00      1.00      1.00        28
#
#     accuracy                           1.00        70
#    macro avg       1.00      1.00      1.00        70
# weighted avg       1.00      1.00      1.00        70

# %% [markdown]
# We can also generate the ROC curve

# %%
le = LabelEncoder()
y_true_num = le.fit_transform(y_test)  # e.g., Calm → 0, Energetic → 1

# %%
y_proba = dt_classifier.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_true_num, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], linestyle='--', color='gray')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# Repeat the ML workflow to train a Decision Tree Regressor and a Linear Regression model, to predict energy.
# Generate a correlation matrix first to exclude features that may be too linearly related. Note that evaluation of a model that predicts a continuous value may not be done using Accuracy, Recall, or Precision.

# %%
def generate_matrix(corr_matrix):
    plt.figure(figsize=(8, 6))
    plt.imshow(corr_matrix, cmap='coolwarm', interpolation='none', aspect='auto')
    plt.colorbar(label='Correlation Coefficient')
    plt.xticks(range(len(corr_matrix)), corr_matrix.columns, rotation=45)
    plt.yticks(range(len(corr_matrix)), corr_matrix.columns)

    # Add correlation coefficients on heatmap
    for i in range(len(corr_matrix)):
        for j in range(len(corr_matrix)):
            plt.text(j, i, f"{corr_matrix.iloc[i, j]:.2f}",
                    ha='center', va='center', color='black')

    plt.title('Correlation Matrix')
    plt.tight_layout()
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, 4 to 685
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              349 non-null    object
#  1   album             349 non-null    object
#  2   artist            349 non-null    object
#  3   id                349 non-null    object
#  4   release_date      349 non-null    object
#  5   popularity        349 non-null    int64
#  6   length            349 non-null    int64
#  7   danceability      349 non-null    float64
#  8   acousticness      349 non-null    float64
#  9   energy            349 non-null    float64
#  10  instrumentalness  349 non-null    float64
#  11  liveness          349 non-null    float64
#  12  valence           349 non-null    float64
#  13  loudness          349 non-null    float64
#  14  speechiness       349 non-null    float64
#  15  tempo             349 non-null    float64
#  16  key               349 non-null    int64
#  17  time_signature    349 non-null    int64
#  18  mood              349 non-null    object
# dtypes: float64(9), int64(4), object(6)
# memory usage: 54.5+ KB

# %%
# extract numerical features + energy from data frame
data = pd.read_csv("https://raw.githubusercontent.com/cristobalvch/Spotify-Machine-Learning/refs/heads/master/data/data_moods.csv")

data = data[['popularity', 'length', 'danceability', 'acousticness', 'instrumentalness', 'liveness', 
        'valence', 'loudness', 'speechiness', 'tempo', 'key', 'time_signature', 'energy', 'mood']]

preds = data[['popularity', 'length', 'danceability', 'acousticness', 'instrumentalness', 'liveness', 
        'valence', 'loudness', 'speechiness', 'tempo', 'key', 'time_signature']]

X = data[['popularity', 'length', 'danceability', 'acousticness', 'instrumentalness', 'liveness', 
        'valence', 'loudness', 'speechiness', 'tempo', 'key', 'time_signature']]
y = data['energy']

# %%
# use df_name.corr() function to get correlation matrix
data_corr = preds.corr()

# %%
# use the generate_matrix() function to visualize the matrix
generate_matrix(data.corr(numeric_only=True)) # I DID use chatgpt for the numeric_only=true

# %%
# use your selected features to train the two models to predict energy
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

y = data["energy"]                               
X = data.drop(columns=["energy"])                
cat = ["mood"]
contin = [c for c in X.columns if c not in cat] 
#dt_regressor = DecisionTreeRegressor(max_depth=3, random_state=42)
#...
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 3619)
z = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), cat),
                            remainder = "passthrough")

dt = DecisionTreeRegressor(max_depth=3, random_state=3619)

pipe = Pipeline([("zscore", z),
                ("dtregression", dt)])

pipe.fit(X,y)

# predict
y_pred = pipe.predict(X)

# assess
print("MSE : ", mean_squared_error(y, y_pred))
print("MAE : ", mean_absolute_error(y, y_pred))
print("MAPE: ", mean_absolute_percentage_error(y, y_pred))
print("R2  : ", r2_score(y, y_pred))
#linear_regressor = LinearRegression()
#...
# Out:
# MSE :  0.012378606227940047
# MAE :  0.08283645274872199
# MAPE:  0.6854717103907639
# R2  :  0.8837038468783797

# %%
y = data["energy"]                               
X = data.drop(columns=["energy"])                
cat = ["mood"]
contin = [c for c in X.columns if c not in cat] 
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 3619)
z = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), cat),
                            remainder = "passthrough")

lr = LinearRegression()

pipe2 = Pipeline([("zscore", z),
                ("linearregression", lr)])

pipe2.fit(X,y)


y_pred = pipe2.predict(X)
print("MSE : ", mean_squared_error(y, y_pred))
print("MAE : ", mean_absolute_error(y, y_pred))
print("MAPE: ", mean_absolute_percentage_error(y, y_pred))
print("R2  : ", r2_score(y, y_pred))
# Out:
# MSE :  0.009002022050443438
# MAE :  0.0711564939113728
# MAPE:  0.779119176598934
# R2  :  0.9154266227146326

# %%
# use your trained models to predict energy on the test set and evaluate their performance using MSE and R² metrics
# what to the model outputs suggest?

# r2_score(y_test, pipe.predict(X_test))
#mean_squared_error(y_test, model_name.predict(X_test))

print("--------------- Decision Tree Regressor ---------------")
print("MSE : ", mean_squared_error(y_test, pipe.predict(X_test)))
print("MAE : ", mean_absolute_error(y_test, pipe.predict(X_test)))
print("MAPE: ", mean_absolute_percentage_error(y_test, pipe.predict(X_test)))
print("R2  : ", r2_score(y_test, pipe.predict(X_test)))
print("\n")
print("--------------- Linear Regression ---------------")
print("MSE : ", mean_squared_error(y_test, pipe2.predict(X_test)))
print("MAE : ", mean_absolute_error(y_test, pipe2.predict(X_test)))
print("MAPE: ", mean_absolute_percentage_error(y_test, pipe2.predict(X_test)))
print("R2  : ", r2_score(y_test, pipe2.predict(X_test)))
# Out:
# --------------- Decision Tree Regressor ---------------
# MSE :  0.01448542424985231
# MAE :  0.08817523264768697
# MAPE:  0.5312616710457582
# R2  :  0.8582642228210873
#
#
# --------------- Linear Regression ---------------
# MSE :  0.009913767462594177
# MAE :  0.07588579413988666
# MAPE:  0.4813030676063036
# R2  :  0.9029965907904886
